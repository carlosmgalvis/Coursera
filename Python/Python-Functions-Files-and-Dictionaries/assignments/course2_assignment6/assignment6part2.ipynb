# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Number of Retweets": [3,1,1,3,6,9,19,0,0,82,0,0,47,2,0,0,4,19,0],
    "Number of Replies":  [0,0,2,1,0,5,0,0,0,2,0,0,0,1,2,0,6,0,0],
    "Positive Score":     [0,2,1,1,2,2,2,0,0,4,0,1,2,1,1,2,3,3,1],
    "Negative Score":     [0,2,0,0,0,0,0,3,2,0,1,0,0,0,0,1,0,1,1],
    "Net Score":          [0,0,1,1,2,2,2,-3,-2,4,-1,1,2,1,1,1,3,2,0]
}

df = pd.DataFrame(data)

plt.figure(figsize=(8,6))
plt.scatter(df["Net Score"], df["Number of Retweets"], c=df["Net Score"], cmap="viridis", s=80)
plt.xlabel("Net Score")
plt.ylabel("Number of Retweets")
plt.title("Scatterplot: Net Score vs Number of Retweets")
plt.grid(True)
plt.show()
